# %%
import pandas as pd
import os
pd.set_option('display.max_columns', None)
pd.set_option('display.max_rows', None)
import shutil

# %%
separator=';'
index='id'

# %%
path_to_data='dane/'

# %%
df=pd.read_csv(path_to_data+'fif_appar_8.csv', sep=separator, index_col=index)
df.head(100)
# Out:
#      plcid                  title addr  modbusAddr  type  dictid  \
# id
# 476    115    Wilgotnosc wzgledna  HR6         NaN     2       0
# 477    115            Temperatura  HR7         NaN     2       0
# 478    115  Wilgotnosc bezwgledna  HR8         NaN     2       0
# 479    115      Punkt rosy/szronu  HR9         NaN     2       0
# 480    116    Wilgotnosc wzgledna  HR6         NaN     2       0
# 481    116            Temperatura  HR7         NaN     2       0
# 482    116  Wilgotnosc bezwgledna  HR8         NaN     2       0
# 483    116      Punkt rosy/szronu  HR9         NaN     2       0
# 484    117    Wilgotnosc wzgledna  HR6         NaN     2       0
# 485    117            Temperatura  HR7         NaN     2       0
# 486    117  Wilgotnosc bezwgledna  HR8         NaN     2       0
# 487    117      Punkt rosy/szronu  HR9         NaN     2       0
# 488    118    Wilgotnosc wzgledna  HR6         NaN     2       0
# ...

# %%
df.dtypes.head()
# Out:
# plcid           int64
# title          object
# addr           object
# modbusAddr    float64
# type            int64
# dtype: object

# %%
df.graph_color.value_counts()
# Out:
# #0066b3    59
# #fcb540    43
# #fff450    43
# #aa55a1    43
# Name: graph_color, dtype: int64

# %%
df.groupby('plcid')
